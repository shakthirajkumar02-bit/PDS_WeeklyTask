# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# plt.style.use('ggplot')
# sns.set(rc={'figure.figsize':(10o,5)})

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\acer\\Desktop\\PDSweeklyTask'

# %%
df = pd.read_csv(r"C:\\Users\\acer\\Desktop\\PDSweeklyTask\airlines_flights_data.csv")

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# Task 1: Data Exploration

# %%
import pandas as pd

df = pd.read_csv("airlines_flights_data.csv")

print(df.head())
print(df.info())
print(df.describe())
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
print(df.dtypes)
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ...

# %% [markdown]
# Task 2: Univariate Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("airlines_flights_data.csv")

df["price"].hist()
plt.show()

df["airline"].value_counts().plot(kind="bar")
plt.show()

df["class"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# Task 3: Bivariate Analysis

# %%
import seaborn as sns

sns.boxplot(x="class",y="price",data=df)
plt.show()

sns.scatterplot(x="duration",y="price",data=df)
plt.show()

# %% [markdown]
# Task 4: Correlation & Feature Engineering

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("airlines_flights_data.csv")
df["class"] = df["class"].astype("category").cat.codes

sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

df["price_per_hour"] = df["price"] /df["duration"]
df["is_direct"] = (df["stops"] ==0).astype(int)

# %% [markdown]
# Task 5: Business Insights

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("airlines_flights_data.csv")

# Top 5 Business Insights
print("1. Average Ticket Price by Airline")
print(df.groupby("airline")["price"].mean())

print("\n2. Average Ticket Price by Class")
print(df.groupby("class")["price"].mean())

print("\n3. Average Ticket Price by Stops")
print(df.groupby("stops")["price"].mean())

print("\n4. Average Ticket Price by Duration")
print(df.groupby("duration")["price"].mean())

print("\n5. Total Flights by Airline")
print(df["airline"].value_counts())

# Recommendations
print("\nRecommendations:")
print("1. Give discounts during low-demand periods.")
print("2. Use dynamic pricing based on demand.")
print("3. Encourage early booking with special offers.")
# Out:
# 1. Average Ticket Price by Airline
# airline
# AirAsia       4091.072742
# Air_India    23507.019112
# GO_FIRST      5652.007595
# Indigo        5324.216303
# SpiceJet      6179.278881
# Vistara      30396.536302
# Name: price, dtype: float64
#
# 2. Average Ticket Price by Class
# class
# Business    52540.081124
# Economy      6572.342383
# Name: price, dtype: float64
#
# 3. Average Ticket Price by Stops
# stops
# one            22900.992482
# two_or_more    14113.450775
# zero            9375.938535
# Name: price, dtype: float64
#
# 4. Average Ticket Price by Duration
# duration
# 0.83      1973.557692
# 0.92      2003.538462
# 1.00      2266.063660
# 1.08      2589.311031
# 1.17      2632.209375
#              ...
# 44.50    32439.000000
# 45.83    25851.333333
# 47.08    17223.000000
# 47.75    31291.500000
# 49.83    20714.500000
# Name: price, Length: 476, dtype: float64
#
# 5. Total Flights by Airline
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# ...
